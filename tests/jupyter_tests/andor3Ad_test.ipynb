# %%
import os 
os.chdir("/home/wvx67826/p99_bluesky/src/")

# %%
import asyncio
from collections import defaultdict
from p99_bluesky.devices.andor2Ad import Andor3Ad,StaticDirectoryProviderPlus 
from p99_bluesky.plans.ad_plans import AdPlan
from ophyd_async.core import DeviceCollector 
from ophyd_async.core._providers import StaticDirectoryProvider
from ophyd_async.core import DetectorTrigger
loop = asyncio.get_event_loop()
from bluesky.run_engine import RunEngine
from bluesky.callbacks.best_effort import BestEffortCallback
from bluesky.plans import count, scan 
bec = BestEffortCallback()
RE = RunEngine({})

# %%
df1 =  StaticDirectoryProviderPlus("/dls/p99/data/2024/cm37284-2/processing/test_bluesky/", "p99-")
with DeviceCollector():
    andor = Andor3Ad(
        "BL99P-EA-DET-01:",
        df1,
        "andor3",
    )

# %%
andor_plans = AdPlan(andor)

# %%
docs = defaultdict(list)

def capture_emitted(name, doc):
    docs[name].append(doc)
RE(andor_plans.tiggerImg(andor,0.1),capture_emitted)
# Out:
# ('07b83650-0cbd-40b5-8586-68b82bba8fa2',)

# %%
docs
# Out:
# defaultdict(list,
#             {'start': [{'uid': '07b83650-0cbd-40b5-8586-68b82bba8fa2',
#                'time': 1716282723.6198845,
#                'versions': {'ophyd': '1.9.0', 'bluesky': '1.13.0a3'},
#                'scan_id': 1,
#                'plan_type': 'generator',
#                'plan_name': 'tiggerImg'}],
#              'descriptor': [{'configuration': {'andor3': {'data': {},
#                  'timestamps': {},
#                  'data_keys': {}}},
#                'data_keys': {'andor3': {'source': 'ca://BL99P-EA-DET-01:HDF5:FullFileName_RBV',
#                  'shape': (2160, 2560),
#                  'dtype': 'array',
#                  'external': 'STREAM:',
#                  'object_name': 'andor3'},
#                 'andor3-sum': {'source': 'ca://BL99P-EA-DET-01:HDF5:FullFileName_RBV',
#                  'shape': (),
#                  'dtype': 'number',
#                  'external': 'STREAM:',
#                  'object_name': 'andor3'}},
#                'name': 'primary',
#                'object_keys': {'andor3': ['andor3', 'andor3-sum']},
#                'run_start': '07b83650-0cbd-40b5-8586-68b82bba8fa2',
#                'time': 1716282724.1987593,
#                'uid': 'dc50cacd-8546-4719-86bb-d6a7a4b20cd5',
#                'hints': {'andor3': {'fields': ['andor3']}}}],
#              'stream_resource': [{'uid': '64629a9a-4db2-49af-9b9a-a8bbf6a0839a',
#                'data_key': 'andor3',
#                'spec': 'AD_HDF5_SWMR_SLICE',
#                'root': '/dls/p99/data/2024/cm37284-2/processing/test_bluesky/',
#                'resource_path': 'p99-andor3-hdf0.h5',
#                'resource_kwargs': {'path': '/entry/data/data',
#                 'multiplier': 1,
#                 'timestamps': '/entry/instrument/NDAttributes/NDArrayTimeStamp'},
#                'path_semantics': 'posix',
#                'run_start': '07b83650-0cbd-40b5-8586-68b82bba8fa2'},
#               {'uid': '11fe3f7c-c670-44e1-9571-9e4b0d73677e',
#                'data_key': 'andor3-sum',
#                'spec': 'AD_HDF5_SWMR_SLICE',
#                'root': '/dls/p99/data/2024/cm37284-2/processing/test_bluesky/',
#                'resource_path': 'p99-andor3-hdf0.h5',
#                'resource_kwargs': {'path': '/entry/instrument/NDAttributes/StatsTotal',
#                 'multiplier': 1,
#                 'timestamps': '/entry/instrument/NDAttributes/NDArrayTimeStamp'},
#                'path_semantics': 'posix',
#                'run_start': '07b83650-0cbd-40b5-8586-68b82bba8fa2'}],
#              'stream_datum': [{'stream_resource': '64629a9a-4db2-49af-9b9a-a8bbf6a0839a',
#                'uid': '64629a9a-4db2-49af-9b9a-a8bbf6a0839a/0',
#                'seq_nums': {'start': 1, 'stop': 2},
#                'indices': {'start': 0, 'stop': 1},
#                'descriptor': 'dc50cacd-8546-4719-86bb-d6a7a4b20cd5'},
#               {'stream_resource': '11fe3f7c-c670-44e1-9571-9e4b0d73677e',
#                'uid': '11fe3f7c-c670-44e1-9571-9e4b0d73677e/0',
#                'seq_nums': {'start': 1, 'stop': 2},
#                'indices': {'start': 0, 'stop': 1},
#                'descriptor': 'dc50cacd-8546-4719-86bb-d6a7a4b20cd5'}],
#              'event': [{'uid': '661b1e2e-a7d8-49c4-a053-8eb0c9c26377',
#                'time': 1716282724.2008898,
#                'data': {},
#                'timestamps': {},
#                'seq_num': 1,
#                'filled': {},
#                'descriptor': 'dc50cacd-8546-4719-86bb-d6a7a4b20cd5'}],
#              'stop': [{'uid': '47152f88-56c1-4c8b-8a5c-c4bc6f0ae690',
#                'time': 1716282724.2011433,
#                'run_start': '07b83650-0cbd-40b5-8586-68b82bba8fa2',
#                'exit_status': 'success',
#                'reason': '',
#                'num_events': {'primary': 1}}]})

# %%
import h5py
k =h5py.File("/dls/p99/data/2024/cm37284-2/processing/test_bluesky/p99-andor3-hdf0.h5", 'r')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
im = ax.imshow(k["entry"]["data"]["data"][0])

# %%
docs = defaultdict(list)
RE(andor_plans.takeImg(exposure = 0.01,
        n_img = 4,
        det_trig =  DetectorTrigger.internal),capture_emitted)
# Out:
# ('3ed0d719-6abd-4656-8757-0187af1ff302',)

# %%
docs
# Out:
# defaultdict(list,
#             {'start': [{'uid': '3ed0d719-6abd-4656-8757-0187af1ff302',
#                'time': 1716282754.2965877,
#                'versions': {'ophyd': '1.9.0', 'bluesky': '1.13.0a3'},
#                'scan_id': 3,
#                'plan_type': 'generator',
#                'plan_name': 'takeImg'}],
#              'descriptor': [{'configuration': {'andor3': {'data': {},
#                  'timestamps': {},
#                  'data_keys': {}}},
#                'data_keys': {'andor3': {'source': 'ca://BL99P-EA-DET-01:HDF5:FullFileName_RBV',
#                  'shape': (2160, 2560),
#                  'dtype': 'array',
#                  'external': 'STREAM:',
#                  'object_name': 'andor3'},
#                 'andor3-sum': {'source': 'ca://BL99P-EA-DET-01:HDF5:FullFileName_RBV',
#                  'shape': (),
#                  'dtype': 'number',
#                  'external': 'STREAM:',
#                  'object_name': 'andor3'}},
#                'name': 'primary',
#                'object_keys': {'andor3': ['andor3', 'andor3-sum']},
#                'run_start': '3ed0d719-6abd-4656-8757-0187af1ff302',
#                'time': 1716282754.297837,
#                'uid': '2fbed214-b998-49af-bc0c-787df1f99254',
#                'hints': {'andor3': {'fields': ['andor3']}}}],
#              'stop': [{'uid': '4d09988e-1029-4c35-b4d5-aa3dd8680554',
#                'time': 1716282755.150117,
#                'run_start': '3ed0d719-6abd-4656-8757-0187af1ff302',
#                'exit_status': 'success',
#                'reason': '',
#                'num_events': {'primary': 0}}]})

# %%
k =h5py.File("/dls/p99/data/2024/cm37284-2/processing/test_bluesky/p99-andor3-hdf3.h5", 'r')

# %%
import math 
data = k["entry"]["data"]["data"]
for i in range(data.len()):
    plt.subplot(math.ceil(data.len()/2.0),2,i+1)   
    plt.imshow(data[i])
